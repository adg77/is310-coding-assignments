# %% [markdown]
# In this Notebook, I plan to explore how the fantasy genre has been dominated by mostly male authors, and how that is slowly chaning over time. Lets begin!

# %%
import pandas as pd
import altair as alt
import matplotlib.pyplot as plt

# %%
novels_df = pd.read_csv('https://raw.githubusercontent.com/melaniewalsh/responsible-datasets-in-context/main/datasets/top-500-novels/library_top_500.csv')
nyt_bestsellers_df = pd.read_csv("https://raw.githubusercontent.com/ecds/post45-datasets/main/nyt_full.tsv", sep='\t')
nyt_bestsellers_df = nyt_bestsellers_df.rename(columns={'title': 'nyt_title'})
nyt_bestsellers_df['title'] = nyt_bestsellers_df['nyt_title'].str.capitalize()
combined_novels_nyt_df = novels_df.merge(nyt_bestsellers_df, how='left', on=['author', 'title'])
combined_novels_nyt_df.columns
# Out:
# Index(['top_500_rank', 'title', 'author', 'pub_year', 'orig_lang', 'genre',
#        'author_birth', 'author_death', 'author_gender', 'author_primary_lang',
#        'author_nationality', 'author_field_of_activity', 'author_occupation',
#        'oclc_holdings', 'oclc_eholdings', 'oclc_total_editions',
#        'oclc_holdings_rank', 'oclc_editions_rank', 'gr_avg_rating',
#        'gr_num_ratings', 'gr_num_reviews', 'gr_avg_rating_rank',
#        'gr_num_ratings_rank', 'oclc_owi', 'author_viaf', 'gr_url', 'wiki_url',
#        'pg_eng_url', 'pg_orig_url', 'year', 'week', 'rank', 'title_id',
#        'nyt_title'],
#       dtype='object')

# %% [markdown]
# After combining the datasets of the Top 500 Greatest Novels and the New York Times Best Sellers list, we have a list of 721 books and authors that were in both sets of the data.

# %%
print(combined_novels_nyt_df['author'].nunique())
# Out:
# 279

# %%
combined_novels_nyt_df['pub_year'] = combined_novels_nyt_df['pub_year'].astype(int)
combined_novels_nyt_df['author_gender'] = combined_novels_nyt_df['author_gender'].astype(str)

# %%
combined_novels_nyt_df = combined_novels_nyt_df.dropna(subset=['pub_year'])

valid_years = combined_novels_nyt_df[(combined_novels_nyt_df['pub_year'] >= 1800) & (combined_novels_nyt_df['pub_year'] <= pd.Timestamp.now().year)]

# Aggregate the data
# Group by year and gender, and count the number of authors
author_counts = valid_years.groupby(['pub_year', 'author_gender']).size().reset_index(name='count')

author_counts['pub_year'] = pd.to_datetime(author_counts['pub_year'], format='%Y')
# Create the Altair chart
chart = alt.Chart(author_counts).mark_line().encode(
    x=alt.X('pub_year:T', title='Year'),
    y=alt.Y('count:Q', title='Number of Authors'),
    color=alt.Color('author_gender:N', title='Gender')
).properties(
    title='Gender Disparity in Authors Over Time'
)

# Display the chart
chart
# Out:
# alt.Chart(...)

# %% [markdown]
# As you can see, this graph ended up being a little wonkey. Lets retry with a scatterplot.

# %%
scatter_plot = alt.Chart(author_counts).mark_circle(size=60).encode(
    x=alt.X('pub_year:T', title='Year'),
    y=alt.Y('count:Q', title='Number of Authors'),
    color=alt.Color('author_gender:N', title='Gender'),
    tooltip=['pub_year:T', 'count:Q', 'author_gender:N']
).properties(
    title='Gender Disparity in Authors Over Time'
)

# Display the scatter plot
scatter_plot
# Out:
# alt.Chart(...)

# %% [markdown]
# This scatterplot still doesn't tell us too much about the gender of popular authors. We can see some clear outlier years more recently, and with a couple exeptions like 1938 having a lot of female authors. Time to look a little deeper into 1938 to see what caused it to have so many female authors.

# %%
female_authors_1938 = combined_novels_nyt_df[(combined_novels_nyt_df['author_gender'] == 'female') & (combined_novels_nyt_df['pub_year'] == 1938)]
print(female_authors_1938)
# Out:
#      top_500_rank         title                    author  pub_year orig_lang  \
# 167           130       Rebecca         Daphne Du Maurier      1938   English
# 168           130       Rebecca         Daphne Du Maurier      1938   English
# 169           130       Rebecca         Daphne Du Maurier      1938   English
# 170           130       Rebecca         Daphne Du Maurier      1938   English
# 171           130       Rebecca         Daphne Du Maurier      1938   English
# 172           130       Rebecca         Daphne Du Maurier      1938   English
# 173           130       Rebecca         Daphne Du Maurier      1938   English
# 174           130       Rebecca         Daphne Du Maurier      1938   English
# 175           130       Rebecca         Daphne Du Maurier      1938   English
# 176           130       Rebecca         Daphne Du Maurier      1938   English
# 177           130       Rebecca         Daphne Du Maurier      1938   English
# 178           130       Rebecca         Daphne Du Maurier      1938   English
# 179           130       Rebecca         Daphne Du Maurier      1938   English
# 180           130       Rebecca         Daphne Du Maurier      1938   English
# 181           130       Rebecca         Daphne Du Maurier      1938   English
# 182           130       Rebecca         Daphne Du Maurier      1938   English
# 183           130       Rebecca         Daphne Du Maurier      1938   English
# 184           130       Rebecca         Daphne Du Maurier      1938   English
# 185           130       Rebecca         Daphne Du Maurier      1938   English
# 186           130       Rebecca         Daphne Du Maurier      1938   English
# 187           130       Rebecca         Daphne Du Maurier      1938   English
# 188           130       Rebecca         Daphne Du Maurier      1938   English
# 189           130       Rebecca         Daphne Du Maurier      1938   English
# 190           130       Rebecca         Daphne Du Maurier      1938   English
# 191           130       Rebecca         Daphne Du Maurier      1938   English
# 192           130       Rebecca         Daphne Du Maurier      1938   English
# 193           130       Rebecca         Daphne Du Maurier      1938   English
# 194           130       Rebecca         Daphne Du Maurier      1938   English
# 195           130       Rebecca         Daphne Du Maurier      1938   English
# 196           130       Rebecca         Daphne Du Maurier      1938   English
# 197           130       Rebecca         Daphne Du Maurier      1938   English
# 198           130       Rebecca         Daphne Du Maurier      1938   English
# 232           164  The Yearling  Marjorie Kinnan Rawlings      1938   English
#
#        genre author_birth author_death author_gender author_primary_lang  ...  \
# 167  romance         1907         1989        female                 eng  ...
# 168  romance         1907         1989        female                 eng  ...
# 169  romance         1907         1989        female                 eng  ...
# 170  romance         1907         1989        female                 eng  ...
# 171  romance         1907         1989        female                 eng  ...
# 172  romance         1907         1989        female                 eng  ...
# 173  romance         1907         1989        female                 eng  ...
# 174  romance         1907         1989        female                 eng  ...
# 175  romance         1907         1989        female                 eng  ...
# 176  romance         1907         1989        female                 eng  ...
# 177  romance         1907         1989        female                 eng  ...
# 178  romance         1907         1989        female                 eng  ...
# 179  romance         1907         1989        female                 eng  ...
https://en.wikipedia.org/wiki/Rebecca_(novel)  NA_not-pub-domain
# 171  https://en.wikipedia.org/wiki/Rebecca_(novel)  NA_not-pub-domain
# 172  https://en.wikipedia.org/wiki/Rebecca_(novel)  NA_not-pub-domain
# 173  https://en.wikipedia.org/wiki/Rebecca_(novel)  NA_not-pub-domain
# 174  https://en.wikipedia.org/wiki/Rebecca_(novel)  NA_not-pub-domain
# 175  https://en.wikipedia.org/wiki/Rebecca_(novel)  NA_not-pub-domain
# 176  https://en.wikipedia.org/wiki/Rebecca_(novel)  NA_not-pub-domain
# 177  https://en.wikipedia.org/wiki/Rebecca_(novel)  NA_not-pub-domain
# 178  https://en.wikipedia.org/wiki/Rebecca_(novel)  NA_not-pub-domain
# 179  https://en.wikipedia.org/wiki/Rebecca_(novel)  NA_not-pub-domain
# 180  https://en.wikipedia.org/wiki/Rebecca_(novel)  NA_not-pub-domain
# 181  https://en.wikipedia.org/wiki/Rebecca_(novel)  NA_not-pub-domain
# 182  https://en.wikipedia.org/wiki/Rebecca_(novel)  NA_not-pub-domain
# 183  https://en.wikipedia.org/wiki/Rebecca_(novel)  NA_not-pub-domain
# 184  https://en.wikipedia.org/wiki/Rebecca_(novel)  NA_not-pub-domain
# 185  https://en.wikipedia.org/wiki/Rebecca_(novel)  NA_not-pub-domain
# 186  https://en.wikipedia.org/wiki/Rebecca_(novel)  NA_not-pub-domain
# 187  https://en.wikipedia.org/wiki/Rebecca_(novel)  NA_not-pub-domain
# 188  https://en.wikipedia.org/wiki/Rebecca_(novel)  NA_not-pub-domain
# 189  https://en.wikipedia.org/wiki/Rebecca_(novel)  NA_not-pub-domain
# 190  https://en.wikipedia.org/wiki/Rebecca_(novel)  NA_not-pub-domain
# 191  https://en.wikipedia.org/wiki/Rebecca_(novel)  NA_not-pub-domain
# 192  https://en.wikipedia.org/wiki/Rebecca_(novel)  NA_not-pub-domain
# 193  https://en.wikipedia.org/wiki/Rebecca_(novel)  NA_not-pub-domain
# 194  https://en.wikipedia.org/wiki/Rebecca_(novel)  NA_not-pub-domain
# 195  https://en.wikipedia.org/wiki/Rebecca_(novel)  NA_not-pub-domain
# 196  https://en.wikipedia.org/wiki/Rebecca_(novel)  NA_not-pub-domain
# 197  https://en.wikipedia.org/wiki/Rebecca_(novel)  NA_not-pub-domain
# 198  https://en.wikipedia.org/wiki/Rebecca_(novel)  NA_not-pub-domain
# 232     https://en.wikipedia.org/wiki/The_Yearling  NA_not-pub-domain
#
#      pg_orig_url    year        week  rank  title_id nyt_title
# 167          NaN  1938.0  1938-10-03   6.0    3727.0   REBECCA
# 168          NaN  1938.0  1938-10-10   2.0    3727.0   REBECCA
# 169          NaN  1938.0  1938-10-17   2.0    3727.0   REBECCA
# 170          NaN  1938.0  1938-10-24   1.0    3727.0   REBECCA
# 171          NaN  1938.0  1938-10-31   1.0    3727.0   REBECCA
# 172          NaN  1938.0  1938-11-07   1.0    3727.0   REBECCA
# 173          NaN  1938.0  1938-11-14   1.0    3727.0   REBECCA
# 174          NaN  1938.0  1938-11-21   1.0    3727.0   REBECCA
# 175          NaN  1938.0  1938-11-28   2.0    3727.0   REBECCA
# 176          NaN  1938.0  1938-12-05   1.0    3727.0   REBECCA
# 177          NaN  1938.0  1938-12-12   1.0    3727.0   REBECCA
# 178          NaN  1938.0  1938-12-19   1.0    3727.0   REBECCA
# 179          NaN  1938.0  1938-12-26   2.0    3727.0   REBECCA
# 180          NaN  1939.0  1939-01-02   2.0    3727.0   REBECCA
# 181          NaN  1939.0  1939-01-09   1.0    3727.0   REBECCA
# 182          NaN  1939.0  1939-01-16   2.0    3727.0   REBECCA
# 183          NaN  1939.0  1939-01-23   2.0    3727.0   REBECCA
# 184          NaN  1939.0  1939-01-30   2.0    3727.0   REBECCA
# 185          NaN  1939.0  1939-02-06   2.0    3727.0   REBECCA
# 186          NaN  1939.0  1939-02-13   2.0    3727.0   REBECCA
# 187          NaN  1939.0  1939-02-20   2.0    3727.0   REBECCA
# 188          NaN  1939.0  1939-02-27   2.0    3727.0   REBECCA
# 189          NaN  1939.0  1939-03-06   2.0    3727.0   REBECCA
# 190          NaN  1939.0  1939-03-13   2.0    3727.0   REBECCA
# 191          NaN  1939.0  1939-03-20   3.0    3727.0   REBECCA
# 192          NaN  1939.0  1939-03-27   5.0    3727.0   REBECCA
# 193          NaN  1939.0  1939-04-03   3.0    3727.0   REBECCA
# 194          NaN  1939.0  1939-04-10   6.0    3727.0   REBECCA
# 195          NaN  1939.0  1939-04-17   6.0    3727.0   REBECCA
# 196          NaN  1939.0  1939-04-24   7.0    3727.0   REBECCA
# 197          NaN  1939.0  1939-05-01   5.0    3727.0   REBECCA
# 198          NaN  1939.0  1939-05-15   7.0    3727.0   REBECCA
# 232          NaN     NaN         NaN   NaN       NaN       NaN
#
# [33 rows x 34 columns]

# %% [markdown]
# It seems this book was listed many times in this dataset. Although interesting to note, it won't help us with looking at the gender of authors over time. More data cleaning must be done.

# %%
unique_authors_df = combined_novels_nyt_df.drop_duplicates(subset=['author'])
unique_authors_df
# Out:
#      top_500_rank                               title                  author  \
# 0               1                         Don Quixote     Miguel de Cervantes
# 1               2    Alice's Adventures in Wonderland           Lewis Carroll
# 2               3  The Adventures of Huckleberry Finn              Mark Twain
# 4               5                     Treasure Island  Robert Louis Stevenson
# 5               6                 Pride and Prejudice             Jane Austen
# ..            ...                                 ...                     ...
# 697           494              The Naked and the Dead           Norman Mailer
# 699           496          Stranger in a Strange Land      Robert A. Heinlein
# 700           497                     Vision in White            Nora Roberts
# 701           498                    The Whipping Boy          Sid Fleischman
# 702           499                                Room           Emma Donoghue
#
#      pub_year orig_lang    genre author_birth author_death author_gender  \
# 0        1605   Spanish   action         1547         1616          male
# 1        1865   English  fantasy         1832         1898          male
# 2        1884   English   action         1835         1910          male
# 4        1883   English   action         1850         1894          male
# 5        1813   English  romance         1775         1817        female
# ..        ...       ...      ...          ...          ...           ...
# 697      1948   English  history         1923         2007          male
# 699      1961   English    scifi         1907         1988          male
# 700      2009   English  romance         1965        ALIVE        female
# 701      1986   English   action         1920         2010          male
# 702      2010   English       na         1969        ALIVE        female
#
#     author_primary_lang  ... author_viaf  \
# 0                   spa  ...    17220427
# 1                   eng  ...    66462036
# 2                   eng  ...    50566653
# 4                   eng  ...    95207986
# 5                   eng  ...   102333412
# ..                  ...  ...         ...
# 697                 eng  ...     7393743
# 699                 eng  ...    12309757
# 700                 eng  ...    66448023
# 701                 eng  ...    66438084
# 702                 eng  ...    39539889
#
#                                                 gr_url  \
# 0    https://www.goodreads.com/book/show/3836.Don_Q...
# 1    https://www.goodreads.com/book/show/24213.Alic...
# 2    https://www.goodreads.com/book/show/2956.The_A...
# 4    https://www.goodreads.com/book/show/295.Treasu...
# 5    https://www.goodreads.com/book/show/1885.Pride...
# ..                                                 ...
# 697                                                NaN
# 699                                                NaN
# 700                                                NaN
# 701                                                NaN
# 702                                                NaN
#
#                                               wiki_url  \
# 0            https://en.wikipedia.org/wiki/Don_Quixote
# 1    https://en.wikipedia.org/wiki/Alice%27s_Advent...
# 2    https://en.wikipedia.org/wiki/Adventures_of_Hu...
# 4        https://en.wikipedia.org/wiki/Treasure_Island
# 5    https://en.wikipedia.org/wiki/Pride_and_Prejudice
# ..                                                 ...
# 697  https://en.wikipedia.org/wiki/The_Naked_and_th...
# 699  https://en.wikipedia.org/wiki/Stranger_in_a_St...
# 700      https://en.wikipedia.org/wiki/Vision_in_White
# 701     https://en.wikipedia.org/wiki/The_Whipping_Boy
# 702         https://en.wikipedia.org/wiki/Room_(novel)
#
#                                             pg_eng_url  \
# 0    https://www.gutenberg.org/cache/epub/996/pg996...
# 1     https://www.gutenberg.org/cache/epub/11/pg11.txt
# 2     https://www.gutenberg.org/cache/epub/76/pg76.txt
# 4    https://www.gutenberg.org/cache/epub/120/pg120...
# 5    https://www.gutenberg.org/cache/epub/1342/pg13...
# ..                                                 ...
# 697                                  NA_not-pub-domain
# 699                                  NA_not-pub-domain
# 700                                  NA_not-pub-domain
# 701                                  NA_not-pub-domain
# 702                                  NA_not-pub-domain
#
#                                            pg_orig_url    year        week  \
# 0    https://www.gutenberg.org/cache/epub/2000/pg20...     NaN         NaN
# 1                                                  NaN     NaN         NaN
# 2                                                  NaN     NaN         NaN
# 4                                                  NaN     NaN         NaN
# 5                                                  NaN     NaN         NaN
# ..                                                 ...     ...         ...
# 697                                                NaN     NaN         NaN
# 699                                                NaN     NaN         NaN
# 700                                                NaN     NaN         NaN
# 701                                                NaN     NaN         NaN
# 702                                                NaN  2010.0  2010-10-03
#
#      rank  title_id nyt_title
# 0     NaN       NaN       NaN
# 1     NaN       NaN       NaN
# 2     NaN       NaN       NaN
# 4     NaN       NaN       NaN
# 5     NaN       NaN       NaN
# ..    ...       ...       ...
# 697   NaN       NaN       NaN
# 699   NaN       NaN       NaN
# 700   NaN       NaN       NaN
# 701   NaN       NaN       NaN
# 702  10.0    3859.0      ROOM
#
# [279 rows x 34 columns]

# %% [markdown]
# We now have a dataset with all unique authors in the datasets, wiht a total of 279. Although looking at this data is not as complete as looking at every book by every author, it will give us a cleaner graph to look at author's genders based on when they wrote the book they were selected for. Lets make another scatterplot to compare and see how different it looks.

# %%
unique_authors_df['pub_year'] = unique_authors_df['pub_year'].astype(str)
unique_authors_df['pub_year'] = pd.to_datetime(unique_authors_df['pub_year'], format='%Y', errors='coerce')
scatter_plot = alt.Chart(unique_authors_df).mark_circle(size=60).encode(
    x=alt.X('pub_year:T', title='Year'),
    y=alt.Y('count()', title='Number of Authors'),
    color=alt.Color('author_gender:N', title='Gender'),
    tooltip=['pub_year:T', 'count()', 'author_gender:N']
).properties(
    title='Gender Disparity in Authors Over Time'
)

# Display the scatter plot
scatter_plot
# Out:
# /var/folders/fp/fz7jly1s1nd0k1gc00ph9l680000gn/T/ipykernel_55692/260561285.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unique_authors_df['pub_year'] = unique_authors_df['pub_year'].astype(str)
# /var/folders/fp/fz7jly1s1nd0k1gc00ph9l680000gn/T/ipykernel_55692/260561285.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unique_authors_df['pub_year'] = pd.to_datetime(unique_authors_df['pub_year'], format='%Y', errors='coerce')
# alt.Chart(...)

# %% [markdown]
# This scatterplot is a little more descriptive. We can see there is some years were 2 female authors made the dataset, but only 1 year (2009) 3 female authors made it, and none for 4 or 5. Now we can start to see the gender disparity between authors in every genre, it's time to focus in on the fantasy genre.

# %%
fantasy_unique_authors_df = unique_authors_df[unique_authors_df['genre'] == 'fantasy']
fantasy_unique_authors_df
# Out:
#      top_500_rank                                  title               author  \
# 1               2       Alice's Adventures in Wonderland        Lewis Carroll
# 10             11                     Gulliver's Travels       Jonathan Swift
# 17             18   The Hobbit, or, There and Back Again       J.R.R. Tolkien
# 29             30                       The Wizard of Oz        L. Frank Baum
# 38             39                The Wind in the Willows      Kenneth Grahame
# 44             45  Harry Potter and the Sorcerer's Stone         J.K. Rowling
# 58             51  The Lion, the Witch, and the Wardrobe           C.S. Lewis
# 66             59                              Peter Pan          J.M. Barrie
# 104            97                        Charlotte's Web           E.B. White
# 251           183                   Bridge to Terabithia   Katherine Paterson
# 301           233                       Tuck Everlasting      Natalie Babbitt
# 342           274                                 Eragon  Christopher Paolini
# 406           325                    The Lightning Thief         Rick Riordan
# 426           345                           Mary Poppins         P.L. Travers
# 427           346                           Artemis Fowl          Eoin Colfer
# 431           350                     The Dark Is Rising         Susan Cooper
# 445           364                      A Game of Thrones   George R.R. Martin
# 524           381             The Indian in the Cupboard     Lynne Reid Banks
# 558           415       Mrs. Frisby and the Rats of NIMH    Robert C. O'Brien
# 591           419               The Once and Future King          T. H. White
# 616           444                           Lost Horizon         James Hilton
# 620           448                               Inkheart       Cornelia Funke
# 658           472                  The Phantom Tollbooth        Norton Juster
#
#       pub_year orig_lang    genre author_birth author_death author_gender  \
# 1   1865-01-01   English  fantasy         1832         1898          male
# 10  1726-01-01   English  fantasy         1667         1745          male
# 17  1937-01-01   English  fantasy         1892         1973          male
# 29  1900-01-01   English  fantasy         1856         1919          male
# 38  1908-01-01   English  fantasy         1859         1932          male
# 44  1997-01-01   English  fantasy         1965        ALIVE        female
# 58  1950-01-01   English  fantasy         1898         1963          male
# 66  1911-01-01   English  fantasy         1860         1937          male
# 104 1952-01-01   English  fantasy         1899         1985          male
# 251 1977-01-01   English  fantasy         1932        ALIVE        female
# 301 1975-01-01   English  fantasy         1932         2016        female
# 342 2002-01-01   English  fantasy         1983        ALIVE          male
# 406 2005-01-01   English  fantasy         1964        ALIVE          male
# 426 1934-01-01   English  fantasy         1899         1996        female
# 427 2001-01-01   English  fantasy         1965        ALIVE          male
# 431 1973-01-01   English  fantasy         1935        ALIVE        female
# 445 1996-01-01   English  fantasy         1948        ALIVE          male
# 524 1980-01-01   English  fantasy         1929        ALIVE        female
# 558 1971-01-01   English  fantasy         1918         1973          male
# 591 1958-01-01   English  fantasy         1906         1964           nan
# 616 1933-01-01   English  fantasy         1900         1954          male
# 620 2003-01-01    German  fantasy         1958        ALIVE        female
# 658 1961-01-01   English  fantasy         1929         2021          male
#
#     author_primary_lang  ... author_viaf  \
# 1                   eng  ...    66462036
# 10                  eng  ...    14777110
# 17                  eng  ...    95218067
# 29                  eng  ...     4926394
# 38                  eng  ...    36919188
# 44                  eng  ...   116796842
# 58                  eng  ...    22144877
# 66                  eng  ...    64001320
# 104                 eng  ...    66475004
# 251                 eng  ...    98108465
# 301                 eng  ...    46781308
# 342                 eng  ...    49468743
# 406                 eng  ...    60214017
# 426                 eng  ...    95161798
# 427                 eng  ...    69145969
# 431                 eng  ...    49344224
# 445                 eng  ...    98636170
# 524                 eng  ...    39373210
# 558                 eng  ...   107012026
# 591                 NaN  ...    19685792
# 616                 eng  ...    36944583
# 620                 ger  ...   102395980
# 658                 eng  ...    39601304
#
#                                                 gr_url  \
# 29    https://www.gutenberg.org/cache/epub/55/pg55.txt          NaN   NaN
# 38   https://www.gutenberg.org/cache/epub/289/pg289...          NaN   NaN
# 44                                   NA_not-pub-domain          NaN   NaN
# 58                                   NA_not-pub-domain          NaN   NaN
# 66    https://www.gutenberg.org/cache/epub/16/pg16.txt          NaN   NaN
# 104                                  NA_not-pub-domain          NaN   NaN
# 251                                  NA_not-pub-domain          NaN   NaN
# 301                                  NA_not-pub-domain          NaN   NaN
# 342                                  NA_not-pub-domain          NaN   NaN
# 406                                  NA_not-pub-domain          NaN   NaN
# 426                                  NA_not-pub-domain          NaN   NaN
# 427                                  NA_not-pub-domain          NaN   NaN
# 431                                  NA_not-pub-domain          NaN   NaN
# 445                                  NA_not-pub-domain          NaN   NaN
# 524                                  NA_not-pub-domain          NaN   NaN
# 558                                  NA_not-pub-domain          NaN   NaN
# 591                                  NA_not-pub-domain          NaN   NaN
# 616                                  NA_not-pub-domain          NaN   NaN
# 620                                  NA_not-pub-domain  unavailable   NaN
# 658                                  NA_not-pub-domain          NaN   NaN
#
#      week  rank  title_id nyt_title
# 1     NaN   NaN       NaN       NaN
# 10    NaN   NaN       NaN       NaN
# 17    NaN   NaN       NaN       NaN
# 29    NaN   NaN       NaN       NaN
# 38    NaN   NaN       NaN       NaN
# 44    NaN   NaN       NaN       NaN
# 58    NaN   NaN       NaN       NaN
# 66    NaN   NaN       NaN       NaN
# 104   NaN   NaN       NaN       NaN
# 251   NaN   NaN       NaN       NaN
# 301   NaN   NaN       NaN       NaN
# 342   NaN   NaN       NaN       NaN
# 406   NaN   NaN       NaN       NaN
# 426   NaN   NaN       NaN       NaN
# 427   NaN   NaN       NaN       NaN
# 431   NaN   NaN       NaN       NaN
# 445   NaN   NaN       NaN       NaN
# 524   NaN   NaN       NaN       NaN
# 558   NaN   NaN       NaN       NaN
# 591   NaN   NaN       NaN       NaN
# 616   NaN   NaN       NaN       NaN
# 620   NaN   NaN       NaN       NaN
# 658   NaN   NaN       NaN       NaN
#
# [23 rows x 34 columns]

# %% [markdown]
# This narrows us down to 23 fantasy authors, with mostly books you probably recognize. You can eyeball the data and see it's mostly male dominated, but we can make one more graph to help us vizualize it.

# %%
gender_counts = fantasy_unique_authors_df['author_gender'].value_counts().reset_index()
gender_counts.columns = ['author_gender', 'count']

# Create the Altair bar chart
bar_chart = alt.Chart(gender_counts).mark_bar().encode(
    x=alt.X('author_gender:N', title='Gender'),
    y=alt.Y('count:Q', title='Number of Authors'),
    color=alt.Color('author_gender:N', title='Gender'),
    tooltip=['author_gender:N', 'count:Q']
).properties(
    title='Number of Unique Authors by Gender'
)

# Display the bar chart
bar_chart
# Out:
# alt.Chart(...)

# %% [markdown]
# The bar chart shows 16 males to 7 females, as after further inspection the one NAN is TH White, a male english author. Although not an overwhelming majority, it is clear fantasy is a mostly male dominated field for authors. Especially in the past, as most of the woman on the fantasy list have released their book within the last 50 years, with the exeception of The Indian in the Cupboard by Lynne Reid Banks.
